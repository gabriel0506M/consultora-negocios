# %%
<!DOCTYPE html>
<html lang="es">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Consultora de Negocios</title>
    <link rel="stylesheet" href="styles.css">
</head>
<body>
    <header>
        <h1>Consultora de Negocios</h1>
        <nav>
            <ul>
                <li><a href="#inicio">Inicio</a></li>
                <li><a href="#nosotros">Nosotros</a></li>
                <li><a href="#servicios">Servicios</a></li>
                <li><a href="#recursos">Recursos</a></li>
                <li><a href="#contacto">Contacto</a></li>
            </ul>
        </nav>
    </header>
    
    <section id="inicio">
        <h2>Bienvenidos a nuestra consultora</h2>
        <p>Ayudamos a las empresas a crecer con estrategias eficientes.</p>
        <img src="images/consultoria.jpg" alt="Consultoría Empresarial">
    </section>
    
    <section id="nosotros">
        <h2>Sobre Nosotros</h2>
        <p>Somos una firma dedicada a la asesoría empresarial.</p>
        <img src="images/nosotros.jpg" alt="Equipo de trabajo">
    </section>
    
    <section id="servicios">
        <h2>Nuestros Servicios</h2>
        <ul>
            <li>Consultoría en administración</li>
            <li>Planificación financiera</li>
            <li>Estrategias de crecimiento</li>
        </ul>
        <img src="images/servicios.jpg" alt="Nuestros servicios">
    </section>
    
    <section id="recursos">
        <h2>Recursos</h2>
        <a href="documento.pdf" download>Descargar guía empresarial</a>
        <img src="images/recursos.jpg" alt="Recursos empresariales">
    </section>
    
    <section id="contacto">
        <h2>Contacto</h2>
        <form>
            <label for="nombre">Nombre:</label>
            <input type="text" id="nombre" name="nombre" required>
            <label for="email">Correo:</label>
            <input type="email" id="email" name="email" required>
            <button type="submit">Enviar</button>
        </form>
        <img src="images/contacto.jpg" alt="Formulario de contacto">
    </section>
    
    <script src="script.js"></script>
</body>
</html>
